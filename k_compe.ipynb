# %% [markdown]
# <a href="https://colab.research.google.com/github/lurodriguezzz/kaggle_/blob/main/k_compe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -q kaggle
from google.colab import files
files.upload()
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets list
! kaggle competitions download -c home-credit-credit-risk-model-stability
! unzip home-credit-credit-risk-model-stability.zip
# Out:
#      <input type="file" id="files-8591ec97-a592-4e07-8e1c-b8cdc7d28a47" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8591ec97-a592-4e07-8e1c-b8cdc7d28a47">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import os
# !pip install kmedoids
# !pip install econml
import sklearn.preprocessing as skp
import sklearn.decomposition as skd
import sklearn.manifold as skm
import sklearn.cluster as skc
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
import sklearn.model_selection as skms
import sklearn.preprocessing as skpp
import sklearn.metrics as skm
import sklearn.pipeline as skpl
import sklearn.neighbors as skn
import sklearn.svm as skv
import sklearn.ensemble as ske
from sklearn.neighbors import KNeighborsClassifier
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.neighbors import NearestNeighbors
from random import sample
from numpy.random import uniform
from math import isnan
from sklearn.cluster import KMeans
import kmedoids
import econml
from sklearn.manifold import TSNE
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.8/468.8 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.9/532.9 kB 24.8 MB/s eta 0:00:00
# ...

# %%
from sys import ps1
base = pd.read_csv('./csv_files/train/train_base.csv')
appr0 = pd.read_csv('./csv_files/train/train_applprev_1_0.csv')
appr1 = pd.read_csv('./csv_files/train/train_applprev_1_1.csv')
appr2 = pd.read_csv('./csv_files/train/train_applprev_2.csv')
cb0 = pd.read_csv('./csv_files/train/train_credit_bureau_a_1_0.csv')
cb1 = pd.read_csv ('./csv_files/train/train_credit_bureau_a_1_1.csv')
cb2 = pd.read_csv('./csv_files/train/train_credit_bureau_a_1_2.csv')
cb3 = pd.read_csv('./csv_files/train/train_credit_bureau_a_1_3.csv')
cba20 = pd.read_csv('./csv_files/train/train_credit_bureau_a_2_0.csv')
cba21 = pd.read_csv('./csv_files/train/train_credit_bureau_a_2_1.csv')
cba210 = pd.read_csv('./csv_files/train/train_credit_bureau_a_2_10.csv')
cba22 = pd.read_csv('./csv_files/train/train_credit_bureau_a_2_2.csv')
cba23 = pd.read_csv('./csv_files/train/train_credit_bureau_a_2_3.csv')
cba24 = pd.read_csv('./csv_files/train/train_credit_bureau_a_2_4.csv')
cba25 = pd.read_csv('./csv_files/train/train_credit_bureau_a_2_5.csv')
cba26 = pd.read_csv('./csv_files/train/train_credit_bureau_a_2_6.csv')
cba27 = pd.read_csv('./csv_files/train/train_credit_bureau_a_2_7.csv')
cba28 = pd.read_csv('./csv_files/train/train_credit_bureau_a_2_8.csv')
cba29 =pd.read_csv('./csv_files/train/train_credit_bureau_a_2_9.csv')
cbb1 = pd.read_csv('./csv_files/train/train_credit_bureau_b_1.csv')
cbb2 = pd.read_csv('./csv_files/train/train_credit_bureau_b_2.csv')
dc = pd.read_csv('./csv_files/train/train_debitcard_1.csv')
dp = pd.read_csv('./csv_files/train/train_deposit_1.csv')
ot = pd.read_csv('./csv_files/train/train_other_1.csv')
ps1 = pd.read_csv('./csv_files/train/train_person_1.csv')
ps2 = pd.read_csv('./csv_files/train/train_person_2.csv')
st0 = pd.read_csv('./csv_files/train/train_static_0_0.csv')
st01 =  pd.read_csv('./csv_files/train/train_static_0_1.csv')
stcb0 =  pd.read_csv('./csv_files/train/train_static_cb_0.csv')
tra =  pd.read_csv('./csv_files/train/train_tax_registry_a_1.csv')
trb = pd.read_csv('./csv_files/train/train_tax_registry_b_1.csv')
trc = pd.read_csv('./csv_files/train/train_tax_registry_c_1.csv')

data = pd.concat([base,appr0,appr1,appr2,cb0,cb1,cb2,cb3,cba20,cba21,cba210,cba22,
                  cba23,cba24,cba25,cba26,cba27,cba28,cba29,cbb1,cbb2,dc,dp,ot,
                  ps1,ps2,st0,st01,stcb0,tra,trb,trc], ignore_index= True)
# Out:
# <ipython-input-7-4a6743941ff2>:3: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   appr0 = pd.read_csv('./csv_files/train/train_applprev_1_0.csv')
# <ipython-input-7-4a6743941ff2>:4: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   appr1 = pd.read_csv('./csv_files/train/train_applprev_1_1.csv')
# <ipython-input-7-4a6743941ff2>:6: DtypeWarning: Columns (11,12,14,30,44,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   cb0 = pd.read_csv('./csv_files/train/train_credit_bureau_a_1_0.csv')

# %%
base = pd.read_csv('./csv_files/train/train_base.csv')
base = base.fillna(base.median())
base.drop('date_decision', inplace = True, axis = 1)
base.drop('MONTH', inplace = True , axis = 1)
base.drop('target',inplace = True , axis = 1)
print(base.shape)
# scaler
scaler = skp.StandardScaler( )
base_norm = pd.DataFrame( scaler.fit_transform( base.values ), index = base.index, columns = base.columns)
base_norm = base_norm.dropna(how='any')
base_norm
base_test = pd.read_csv('./csv_files/test/test_base.csv')
btest_norm =pd.DataFrame( scaler.fit_transform( base.values ), index = base.index, columns = base.columns)
btest_norm = btest_norm.dropna(how='any')
# Out:
# <ipython-input-3-dacb11f19dc2>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   base = base.fillna(base.median())
# (1526659, 2)

# %%
base_norm.shape
# Out:
# (1526659, 2)

# %%
from numpy.random import seed
from sklearn.preprocessing import minmax_scale
from sklearn.model_selection import train_test_split
from keras.layers import Input, Dense
from keras.models import Model

# %%
encoding_dim = 200
ncol = base_norm.shape[1]

# %%
# Implementation of the Autoencoder Model
# input from df_features, dense64, leakyrelu, dense32, leakyrelu, dense16, tanh
input_dim = Input(shape = (ncol, ))
# Encoder Layers
encoded1 = Dense(3000, activation = 'relu')(input_dim)
encoded2 = Dense(2750, activation = 'relu')(encoded1)
encoded3 = Dense(2500, activation = 'relu')(encoded2)
encoded4 = Dense(2250, activation = 'relu')(encoded3)
encoded5 = Dense(2000, activation = 'relu')(encoded4)
encoded6 = Dense(1750, activation = 'relu')(encoded5)
encoded7 = Dense(1500, activation = 'relu')(encoded6)
encoded8 = Dense(1250, activation = 'relu')(encoded7)
encoded9 = Dense(1000, activation = 'relu')(encoded8)
encoded10 = Dense(750, activation = 'relu')(encoded9)
encoded11 = Dense(500, activation = 'relu')(encoded10)
encoded12 = Dense(250, activation = 'relu')(encoded11)
encoded13 = Dense(encoding_dim, activation = 'relu')(encoded12)

# Decoder Layers
decoded1 = Dense(250, activation = 'relu')(encoded13)
decoded2 = Dense(500, activation = 'relu')(decoded1)
decoded3 = Dense(750, activation = 'relu')(decoded2)
decoded4 = Dense(1000, activation = 'relu')(decoded3)
decoded5 = Dense(1250, activation = 'relu')(decoded4)
decoded6 = Dense(1500, activation = 'relu')(decoded5)
decoded7 = Dense(1750, activation = 'relu')(decoded6)
decoded8 = Dense(2000, activation = 'relu')(decoded7)
decoded9 = Dense(2250, activation = 'relu')(decoded8)
decoded10 = Dense(2500, activation = 'relu')(decoded9)
decoded11 = Dense(2750, activation = 'relu')(decoded10)
decoded12 = Dense(3000, activation = 'relu')(decoded11)
decoded13 = Dense(ncol, activation = 'sigmoid')(decoded12)

autoencoder = Model(inputs = input_dim, outputs = decoded13)

# Compile the Model
autoencoder.compile(optimizer = 'adadelta', loss = 'binary_crossentropy')

# %%
autoencoder.fit(base_norm, base_norm, epochs = 5, batch_size = 380, shuffle = False, validation_data = (btest_norm, btest_norm))
encoder = Model(inputs = input_dim, outputs = encoded13)
encoded_input = Input(shape = (encoding_dim, ))

encoded_train = pd.DataFrame(encoder.predict(base_norm))
encoded_train = encoded_train.add_prefix('feature_')

encoded_test = pd.DataFrame(encoder.predict(btest_norm))
encoded_test = encoded_test.add_prefix('feature_')
# Out:
# Epoch 1/5
# 4018/4018 [==============================] - 328s 82ms/step - loss: 60918938474902432915811991552.0000 - val_loss: 60918905418337052828295495680.0000
# Epoch 2/5
# 4018/4018 [==============================] - 308s 77ms/step - loss: 60918900695970569958650281984.0000 - val_loss: 60918891251237604219359854592.0000
# Epoch 3/5
# 4018/4018 [==============================] - 308s 77ms/step - loss: 60918886528871121349714640896.0000 - val_loss: 60918877084138155610424213504.0000
# Epoch 4/5
# 4018/4018 [==============================] - 326s 81ms/step - loss: 60918877084138155610424213504.0000 - val_loss: 60918877084138155610424213504.0000
# Epoch 5/5
# ...
# 47709/47709 [==============================] - 94s 2ms/step

# %%
encoded_train
encoded_train_n = encoded_train.loc[:, (encoded_train != 0).any(axis=0)]
encoded_train_n
encoded_test_n = encoded_test.loc[:, (encoded_test != 0).any(axis=0)]
encoded_test_n
# Out:
#             feature_0     feature_1     feature_2     feature_4     feature_5  \
# 0        1.045560e+07  6.771665e+06  87019.960938  1.232740e+07  1.210724e+07
# 1        1.045560e+07  6.771666e+06  87020.117188  1.232740e+07  1.210725e+07
# 2        1.045560e+07  6.771668e+06  87020.070312  1.232740e+07  1.210725e+07
# 3        1.045560e+07  6.771669e+06  87020.054688  1.232741e+07  1.210725e+07
# 4        1.045560e+07  6.771670e+06  87020.085938  1.232741e+07  1.210725e+07
# ...               ...           ...           ...           ...           ...
# 1526654  3.495113e+03  1.944702e+04  16307.453125  3.294370e+03  2.632141e+04
# 1526655  3.495131e+03  1.944705e+04  16307.461914  3.294385e+03  2.632145e+04
# 1526656  3.495182e+03  1.944709e+04  16307.467773  3.294448e+03  2.632151e+04
# 1526657  3.495090e+03  1.944703e+04  16307.470703  3.294339e+03  2.632141e+04
# 1526658  3.495152e+03  1.944708e+04  16307.479492  3.294411e+03  2.632149e+04
#
# ...

# %%
import torch
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# Sample data
X = torch.tensor(encoded_test_n.values)


# Calculate pairwise Euclidean distances using PyTorch
distances = torch.cdist(X, X, p=2) # p=2 for Euclidean distance

# Convert distances to numpy array for SciPy usage
distances = distances.numpy()

# Perform hierarchical clustering using SciPy
Z = linkage(distances, 'single')

# Determine the clusters, setting a threshold to cut the dendrogram
df['Cluster'] = fcluster(Z , t=10, criterion='distance')

# %%
cluster = pd.concat([df,base_new],ignore_index= True)
c0 = pd.query('Cluster == 0')
#...

# %%
base
# Out:
#          case_id  WEEK_NUM
# 0              0         0
# 1              1         0
# 2              2         0
# 3              3         0
# 4              4         0
# ...          ...       ...
# 1526654  2703450        91
# 1526655  2703451        91
# 1526656  2703452        91
# 1526657  2703453        91
# 1526658  2703454        91
#
# [1526659 rows x 2 columns]

# %%
ndata = pd.concat([c0,c1,c2,c3,c4,c5,c6,c7], ignore_index= True)
from scipy.stats import ttest_ind
_, p = ttest_ind(base.case_id,ndata.case_id)
print(f'p={p:.3f}')

# interpret
alpha = 0.05  # significance level
if p > alpha:
    print('same distributions/same group mean (fail to reject H0 - we do not have enough evidence to reject H0)')
else:
    print('different distributions/different group mean (reject H0)')


from scipy.stats import ttest_ind
_, p = ttest_ind(base.WEEK_NUM,ndata.WEEK_NUM)
print(f'p={p:.3f}')

# interpret
alpha = 0.05  # significance level
if p > alpha:
    print('same distributions/same group mean (fail to reject H0 - we do not have enough evidence to reject H0)')
else:
    print('different distributions/different group mean (reject H0)')
# Out:
# p=0.000
# different distributions/different group mean (reject H0)
# p=0.000
# different distributions/different group mean (reject H0)
